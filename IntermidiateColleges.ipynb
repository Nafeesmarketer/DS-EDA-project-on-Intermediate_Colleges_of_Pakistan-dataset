# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/ACP.csv",index_col="Name")

# %%
df.head()
# Out:
#                                                                                             Location  \
# Name
# Campus.pk Lahore                                   Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                              Sector H-8, Islamabad-44000
# Government College University Gcu Lahore                   GC University, Katchery Road Lahore 54000
# Govt College University GCU Faisalabad                                  Kotwali Rd, Faisalabad 38000
# Lahore College For Women University (Lcwu) Lahore                Near Wapda Flats, Jail Road, Lahore
#
#                                                                                        Study Program  \
# Name
# Campus.pk Lahore                                                 FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad        FSc Pre Engineering ICs Computer Science FSc P...
# ...

# %%
df.tail(5)
# Out:
#                                                                   Location  \
# Name
# Riphah International College Lodhran  Riphah International College Lodhran
# Govt College of Education Bagh                           Bagh Azad Kashmir
# Riphah International College Swat        Riphah International College Swat
# Riphah International College Dina        Riphah International College Dina
# Riphah International College Dargai    Riphah International College Dargai
#
#                                                                           Study Program  \
# Name
# Riphah International College Lodhran    Fsc Pre Engineering FSc Pre Medical ICS ICOM FA
# Govt College of Education Bagh        FA ICS Computer Science FSc Pre Engineering IC...
# Riphah International College Swat       Fsc Pre Engineering FSc Pre Medical ICS ICOM FA
# Riphah International College Dina       Fsc Pre Engineering FSc Pre Medical ICS ICOM FA
# ...

# %%
df.shape
# Out:
# (1630, 5)

# %%
df.dtypes
# Out:
# Location         object
# Study Program    object
# Sector           object
# Affiliation      object
# Rating           object
# dtype: object

# %%
df.describe()
# Out:
#        Location                                      Study Program   Sector  \
# count      1626                                               1630     1101
# unique     1573                                                774        2
# top     Chakwal  FA ICS Computer Science FSc Pre Medical FSc Pr...  Private
# freq         11                                                 49      562
#
#                    Affiliation Rating
# count                      155   1630
# unique                      97     21
# top     University of Sargodha     0*
# freq                         7   1119

# %%
df["Sector"].describe()
# Out:
# count        1101
# unique          2
# top       Private
# freq          562
# Name: Sector, dtype: object

# %%
df["Rating"].describe()
# Out:
# count     1630
# unique      21
# top         0*
# freq      1119
# Name: Rating, dtype: object

# %%
df["Location"].describe()
# Out:
# count        1626
# unique       1573
# top       Chakwal
# freq           11
# Name: Location, dtype: object

# %%
df["Study Program"].describe()
# Out:
# count                                                  1630
# unique                                                  774
# top       FA ICS Computer Science FSc Pre Medical FSc Pr...
# freq                                                     49
# Name: Study Program, dtype: object

# %%
df["Affiliation"].describe()
# Out:
# count                        155
# unique                        97
# top       University of Sargodha
# freq                           7
# Name: Affiliation, dtype: object

# %%
df.iloc[1300]
# Out:
# Location                             5-Khayaban-e-Sadiq, Sargodha.
# Study Program    FA Icom FSc Pre Engreening FSc Pre Medical ICs...
# Sector                                                     Private
# Affiliation                                                    NaN
# Rating                                                          0*
# Name: Al-Suffah Girls College, dtype: object

# %%
df.iloc[234]
# Out:
# Location         Plot#291/2, C-1 Opposite Govt Girls High Schoo...
# Study Program      FSc Pre Medical Fsc Pre Engineering ICS FA ICom
# Sector                                                         NaN
# Affiliation                                                    NaN
# Rating                                                          1*
# Name: NISA Girls College Lahore, dtype: object

# %%
df.count()
# Out:
# Location         1626
# Study Program    1630
# Sector           1101
# Affiliation       155
# Rating           1630
# dtype: int64

# %%
#before removing duplicate rows
df.shape
# Out:
# (1630, 5)

# %%
d_r_df=df[df.duplicated()]
print("number of duplicated rows :",d_r_df.shape)
# Out:
# number of duplicated rows : (5, 5)

# %%
df=df.drop_duplicates()

# %%
#afer removing duplicate rows
df.shape
# Out:
# (1625, 5)

# %%
df.count()
# Out:
# Location         1621
# Study Program    1625
# Sector           1096
# Affiliation       155
# Rating           1625
# dtype: int64

# %%
#showcasing column with there null values numbers
print(df.isnull().sum())
# Out:
# Location            4
# Study Program       0
# Sector            529
# Affiliation      1470
# Rating              0
# dtype: int64

# %%
#detecting outliers
# !pip install seaborn

# %%
#detecting outliers
import seaborn as sns
sns.boxplot(x=df["Affiliation"])
# Out:
# <Axes: xlabel='Affiliation'>

# %%
sns.boxplot(x=df["Study Program"])
# Out:
# <Axes: xlabel='Study Program'>

# %%
# !pip install matplotlib

# %%
import matplotlib as plt

# %%
df.info(['Affiliation'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1625 entries, Campus.pk Lahore to Riphah International College Dargai
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       1621 non-null   object
#  1   Study Program  1625 non-null   object
#  2   Sector         1096 non-null   object
#  3   Affiliation    155 non-null    object
#  4   Rating         1625 non-null   object
# dtypes: object(5)
# memory usage: 140.7+ KB

# %%
df.head()
# Out:
#                                                                                             Location  \
# Name
# Campus.pk Lahore                                   Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                              Sector H-8, Islamabad-44000
# Government College University Gcu Lahore                   GC University, Katchery Road Lahore 54000
# Govt College University GCU Faisalabad                                  Kotwali Rd, Faisalabad 38000
# Lahore College For Women University (Lcwu) Lahore                Near Wapda Flats, Jail Road, Lahore
#
#                                                                                        Study Program  \
# Name
# Campus.pk Lahore                                                 FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad        FSc Pre Engineering ICs Computer Science FSc P...
# ...

# %%
objcat=['Sector','Rating']
for colname in objcat:
  df[colname]=df[colname].astype('category')

# %%
df.head()
# Out:
#                                                                                             Location  \
# Name
# Campus.pk Lahore                                   Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                              Sector H-8, Islamabad-44000
# Government College University Gcu Lahore                   GC University, Katchery Road Lahore 54000
# Govt College University GCU Faisalabad                                  Kotwali Rd, Faisalabad 38000
# Lahore College For Women University (Lcwu) Lahore                Near Wapda Flats, Jail Road, Lahore
#
#                                                                                        Study Program  \
# Name
# Campus.pk Lahore                                                 FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad        FSc Pre Engineering ICs Computer Science FSc P...
# ...

# %%
Sector=pd.get_dummies(df['Sector'],drop_first=True)
Rating=pd.get_dummies(df['Rating'],drop_first=True)

# %%
df=pd.concat([df,Sector,Rating],axis=1)

# %%
df.head(2)
# Out:
#                                                                                       Location  \
# Name
# Campus.pk Lahore                             Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                        Sector H-8, Islamabad-44000
#
#                                                                                  Study Program  \
# Name
# Campus.pk Lahore                                           FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad  FSc Pre Engineering ICs Computer Science FSc P...
#
#                                               Sector Affiliation Rating  \
# Name
# Campus.pk Lahore                             Private         ads     0*
# Allama Iqbal Open University Aiou Islamabad   Public         NaN     5*
#
#                                              Public  0.25*   0.5*  0.75*  \
# Name
# Campus.pk Lahore                              False  False  False  False
# ...

# %%
df.drop(['Sector','Rating'],axis=1,inplace=True)
df.head()
# Out:
#                                                                                             Location  \
# Name
# Campus.pk Lahore                                   Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                              Sector H-8, Islamabad-44000
# Government College University Gcu Lahore                   GC University, Katchery Road Lahore 54000
# Govt College University GCU Faisalabad                                  Kotwali Rd, Faisalabad 38000
# Lahore College For Women University (Lcwu) Lahore                Near Wapda Flats, Jail Road, Lahore
#
#                                                                                        Study Program  \
# Name
# Campus.pk Lahore                                                 FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad        FSc Pre Engineering ICs Computer Science FSc P...
# ...

# %%
df.shape
# Out:
# (1625, 24)

# %%
df.drop("Affiliation",axis=1,inplace=True)

# %%
df.count()
# Out:
# Location         1621
# Study Program    1625
# Public           1625
# 0.25*            1625
# 0.5*             1625
# 0.75*            1625
# 1*               1625
# 1.25*            1625
# 1.5*             1625
# 1.75*            1625
# 2*               1625
# 2.25*            1625
# 2.5*             1625
# 2.75*            1625
# 3*               1625
# 3.25*            1625
# 3.5*             1625
# 3.75*            1625
# 4*               1625
# 4.25*            1625
# 4.5*             1625
# 4.75*            1625
# 5*               1625
# dtype: int64

# %%
df.head()
# Out:
#                                                                                             Location  \
# Name
# Campus.pk Lahore                                   Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                              Sector H-8, Islamabad-44000
# Government College University Gcu Lahore                   GC University, Katchery Road Lahore 54000
# Govt College University GCU Faisalabad                                  Kotwali Rd, Faisalabad 38000
# Lahore College For Women University (Lcwu) Lahore                Near Wapda Flats, Jail Road, Lahore
#
#                                                                                        Study Program  \
# Name
# Campus.pk Lahore                                                 FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad        FSc Pre Engineering ICs Computer Science FSc P...
# ...

# %%
df=drop(inplace=True)

# %%
# prompt: romoving rows containg missing values

df = df.dropna()

# %%
df.count()
# Out:
# Location         1621
# Study Program    1621
# Public           1621
# 0.25*            1621
# 0.5*             1621
# 0.75*            1621
# 1*               1621
# 1.25*            1621
# 1.5*             1621
# 1.75*            1621
# 2*               1621
# 2.25*            1621
# 2.5*             1621
# 2.75*            1621
# 3*               1621
# 3.25*            1621
# 3.5*             1621
# 3.75*            1621
# 4*               1621
# 4.25*            1621
# 4.5*             1621
# 4.75*            1621
# 5*               1621
# dtype: int64

# %%
#change the interies of catogorical variable colum from true false to 1 and 0

df = df.replace(to_replace=True, value=1)
df = df.replace(to_replace=False, value=0)

# %%
df.head(2)
# Out:
#                                                                                       Location  \
# Name
# Campus.pk Lahore                             Office 206, 2nd Floor Siddique Trade Center Ma...
# Allama Iqbal Open University Aiou Islamabad                        Sector H-8, Islamabad-44000
#
#                                                                                  Study Program  \
# Name
# Campus.pk Lahore                                           FSc Pre Engineering Fsc Pre Medical
# Allama Iqbal Open University Aiou Islamabad  FSc Pre Engineering ICs Computer Science FSc P...
#
#                                              Public  0.25*  0.5*  0.75*  1*  \
# Name
# Campus.pk Lahore                                  0      0     0      0   0
# Allama Iqbal Open University Aiou Islamabad       1      0     0      0   0
#
#                                              1.25*  1.5*  1.75*  ...  2.75*  \
# ...
